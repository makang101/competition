# %%
import xml.sax
import os

# %%
class ButterflyHandler(xml.sax.ContentHandler):
    def __init__(self):
        # self.filename = ''
        # self.path = ''
        self.butterflyname = ''
        self.CurrentData = ''     #可以没有
    def startElement(self, tag, atr):
        self.CurrentData = tag
        
    def endElement(self, tag):
        if tag == 'name':
            dict['butterflyname'] = self.butterflyname

    def characters(self, content):
        if self.CurrentData == 'name':
            self.butterflyname = content

# %%
if __name__ == '__main__':
    dict_count = {}
    dict = {}
    filepath = input('enter your analy file path:')
    filenames = os.listdir(filepath)
    #print(filenames)
    for f in filenames:
        parser = xml.sax.make_parser()
        parser.setFeature(xml.sax.handler.feature_namespaces,0)
        handler = ButterflyHandler()
        parser.setContentHandler(handler)
        f = os.sep.join([filepath, f]) 
        parser.parse(f)
        #print(dict['butterflyname'])
        if dict['butterflyname'] in dict_count:
            dict_count[dict['butterflyname']] += 1
        else:
            dict_count[dict['butterflyname']] = 1
    for k,v in dict_count.items():
        print(k,v)
    print(len(dict_count))
# Out:
# enter your analy file path:C:\Users\Administrator\work\parse_xml\第三届中国数据挖掘大赛-蝴蝶训练集\Annotations
# 巴黎翠凤蝶 23
# 柑橘凤蝶 23
# 玉带凤蝶 1
# 碧凤蝶 43
# 红基美凤蝶 21
# 蓝凤蝶 10
# 金裳凤蝶 3
# 青凤蝶 8
# 朴喙蝶 3
# 密纹飒弄蝶 2
# 小黄斑弄蝶 2
# 无斑珂弄蝶 4
# 直纹稻弄蝶 7
# 花弄蝶 18
# 隐纹谷弄蝶 4
# 绢斑蝶 1
# 虎斑蝶 1
# 亮灰蝶 9
# 咖灰蝶 3
# 大紫琉璃灰蝶 25
# 婀灰蝶 10
# 曲纹紫灰蝶 3
# 波太玄灰蝶 9
# 玄灰蝶 2
# 红灰蝶 7
# 线灰蝶 11
# 维纳斯眼灰蝶 1
# 艳灰蝶 2
# 蓝灰蝶 5
# 青海红珠灰蝶 6
# 古北拟酒眼蝶 3
# 阿芬眼蝶 35
# 拟稻眉眼蝶 2
# 牧女珍眼蝶 8
# 白眼蝶 9
# 菩萨酒眼蝶 1
# 西门珍眼蝶 2
# 边纹黛眼蝶 1
# 云粉蝶 3
# 侏粉蝶 1
# 大卫粉蝶 6
# 大翅绢粉蝶 5
# 宽边黄粉蝶 22
# 山豆粉蝶 1
# 橙黄豆粉蝶 2
# 突角小粉蝶 5
# 箭纹云粉蝶 3
# 箭纹绢粉蝶 5
# 红襟粉蝶 1
# 绢粉蝶 2
# 菜粉蝶 4
# 镉黄迁粉蝶 2
# 黎明豆粉蝶 2
# 依帕绢蝶 2
# 四川绢蝶 1
# 珍珠绢蝶 3
# 蛇目褐蚬蝶 13
# 中环蛱蝶 1
# 云豹蛱蝶 3
# 伊诺小豹蛱蝶 8
# 小红蛱蝶 3
# 扬眉线蛱蝶 35
# 斐豹蛱蝶 1
# 曲斑珠蛱蝶 2
# 柱菲蛱蝶 4
# 柳紫闪蛱蝶 5
# 灿福蛱蝶 6
# 玄珠带蛱蝶 2
# 珍蛱蝶 2
# 琉璃蛱蝶 3
# 白钩蛱蝶 1
# 秀蛱蝶 4
# 绢蛱蝶 3
# 绿豹蛱蝶 5
# 网蛱蝶 7
# 美眼蛱蝶 2
# 翠蓝眼蛱蝶 4
# 老豹蛱蝶 5
# 荨麻蛱蝶 5
# 虬眉带蛱蝶 2
# 蟾福蛱蝶 4
# 钩翅眼蛱蝶 2
# 银斑豹蛱蝶 61
# 银豹蛱蝶 2
# 链环蛱蝶 2
# 锦瑟蛱蝶 1
# 黄环蛱蝶 13
# 黄钩蛱蝶 20
# 黑网蛱蝶 1
# 尖翅翠蛱蝶 7
# 素弄蝶 26
# 翠袖锯眼蝶 28
# 蓝点紫斑蝶 10
# 雅弄蝶 20
# 94
